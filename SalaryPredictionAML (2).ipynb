# %% [markdown]
# # EXPLORING DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("/content/drive/MyDrive/data/salaryprediction.csv")

# %%
dataset.head(5)
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    CAPITALGAIN  CAPITALLOSS  HOURSPERWEEK   NATIVECOUNTRY  ABOVE50K
# 0         2174            0            40   United-States         0
# ...

# %%
#SHAPE OF DATA(DIMENTIONS)
dataset.shape
# Out:
# (32561, 15)

# %%
dataset.info()
dataset.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AGE            32561 non-null  int64
#  1   WORKCLASS      32561 non-null  object
#  2   FNLWGT         32561 non-null  int64
#  3   EDUCATION      32561 non-null  object
#  4   EDUCATIONNUM   32561 non-null  int64
#  5   MARITALSTATUS  32561 non-null  object
#  6   OCCUPATION     32561 non-null  object
#  7   RELATIONSHIP   32561 non-null  object
#  8   RACE           32561 non-null  object
#  9   SEX            32561 non-null  object
#  10  CAPITALGAIN    32561 non-null  int64
#  11  CAPITALLOSS    32561 non-null  int64
#  12  HOURSPERWEEK   32561 non-null  int64
#  13  NATIVECOUNTRY  32561 non-null  object
#  14  ABOVE50K       32561 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# ...

# %%
#GENERATING INSGIHTS
dataset.describe()
# Out:
#                 AGE        FNLWGT  EDUCATIONNUM   CAPITALGAIN   CAPITALLOSS  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        HOURSPERWEEK      ABOVE50K
# count  32561.000000  32561.000000
# mean      40.437456      0.240810
# std       12.347429      0.427581
# min        1.000000      0.000000
# 25%       40.000000      0.000000
# 50%       40.000000      0.000000
# 75%       45.000000      0.000000
# ...

# %% [markdown]
# ## FINDING NULL VALUES

# %%
dataset['WORKCLASS'].value_counts()
#we have ? values
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: WORKCLASS, dtype: int64

# %%
dataset['WORKCLASS'].replace(' ?', np.nan, inplace=True)
#replacing null values in workclass by Nan

# %%
dataset['OCCUPATION'].value_counts()
#WE have ? values
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: OCCUPATION, dtype: int64

# %%
dataset['OCCUPATION'].replace(' ?', np.nan, inplace=True)
#replacing null values in occupation by NaN

# %%
dataset['NATIVECOUNTRY'].value_counts()
#we have ? values
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
dataset['NATIVECOUNTRY'].replace(' ?', np.nan, inplace=True)
#replacing null values in nativvecountry by Nan

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AGE            32561 non-null  int64
#  1   WORKCLASS      30725 non-null  object
#  2   FNLWGT         32561 non-null  int64
#  3   EDUCATION      32561 non-null  object
#  4   EDUCATIONNUM   32561 non-null  int64
#  5   MARITALSTATUS  32561 non-null  object
#  6   OCCUPATION     30718 non-null  object
#  7   RELATIONSHIP   32561 non-null  object
#  8   RACE           32561 non-null  object
#  9   SEX            32561 non-null  object
#  10  CAPITALGAIN    32561 non-null  int64
#  11  CAPITALLOSS    32561 non-null  int64
#  12  HOURSPERWEEK   32561 non-null  int64
#  13  NATIVECOUNTRY  31978 non-null  object
#  14  ABOVE50K       32561 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %% [markdown]
# ## GENERATING DUPLICATE COLUMNS FOR ENCODING (Changing feature type from object to int by mapping through a dict)

# %%
dataset = dataset.assign(workclass_encoder=dataset['WORKCLASS'],education_encoder=dataset['EDUCATION'],maritalStatus_encoder=dataset['MARITALSTATUS'],
                         occupation_encoder=dataset['OCCUPATION'],relationship_encoder=dataset['RELATIONSHIP'],race_encoder=dataset['RACE'],
                         sex_encoder=dataset['SEX'],nativeCountry_encoder=dataset['NATIVECOUNTRY'])
dataset.head(5)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE                    32561 non-null  int64
#  1   WORKCLASS              30725 non-null  object
#  2   FNLWGT                 32561 non-null  int64
#  3   EDUCATION              32561 non-null  object
#  4   EDUCATIONNUM           32561 non-null  int64
#  5   MARITALSTATUS          32561 non-null  object
#  6   OCCUPATION             30718 non-null  object
#  7   RELATIONSHIP           32561 non-null  object
#  8   RACE                   32561 non-null  object
#  9   SEX                    32561 non-null  object
#  10  CAPITALGAIN            32561 non-null  int64
#  11  CAPITALLOSS            32561 non-null  int64
#  12  HOURSPERWEEK           32561 non-null  int64
#  13  NATIVECOUNTRY          31978 non-null  object
# ...

# %%
dataset.isnull().sum()
# Out:
# AGE                         0
# WORKCLASS                1836
# FNLWGT                      0
# EDUCATION                   0
# EDUCATIONNUM                0
# MARITALSTATUS               0
# OCCUPATION               1843
# RELATIONSHIP                0
# RACE                        0
# SEX                         0
# CAPITALGAIN                 0
# CAPITALLOSS                 0
# HOURSPERWEEK                0
# NATIVECOUNTRY             583
# ABOVE50K                    0
# workclass_encoder        1836
# education_encoder           0
# maritalStatus_encoder       0
# occupation_encoder       1843
# relationship_encoder        0
# race_encoder                0
# sex_encoder                 0
# nativeCountry_encoder     583
# dtype: int64

# %%
#Dropping null values
dataset = dataset.dropna()

# %%
dataset.isnull().sum()
#No null values in the dataset now
# Out:
# AGE                      0
# WORKCLASS                0
# FNLWGT                   0
# EDUCATION                0
# EDUCATIONNUM             0
# MARITALSTATUS            0
# OCCUPATION               0
# RELATIONSHIP             0
# RACE                     0
# SEX                      0
# CAPITALGAIN              0
# CAPITALLOSS              0
# HOURSPERWEEK             0
# NATIVECOUNTRY            0
# ABOVE50K                 0
# workclass_encoder        0
# education_encoder        0
# maritalStatus_encoder    0
# occupation_encoder       0
# relationship_encoder     0
# race_encoder             0
# sex_encoder              0
# nativeCountry_encoder    0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
dataset.head(5)
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0          State-gov         Bachelors
# ...

# %%
workclass_encoded = {x:y for y,x in enumerate(set(dataset["workclass_encoder"]))}
dataset["workclass_encoder"] = dataset['workclass_encoder'].astype("category")
dataset["workclass_encoder"] = dataset["workclass_encoder"].apply(lambda x: workclass_encoded[x])
print(workclass_encoded)
dataset.head(5)
# dataset['workclass_encoder']= dataset['workclass_encoder'].astype('int')
# Out:
# {' Federal-gov': 0, ' Local-gov': 1, ' State-gov': 2, ' Private': 3, ' Self-emp-not-inc': 4, ' Self-emp-inc': 5, ' Without-pay': 6}
# <ipython-input-20-755459d0c24b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["workclass_encoder"] = dataset['workclass_encoder'].astype("category")
# <ipython-input-20-755459d0c24b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["workclass_encoder"] = dataset["workclass_encoder"].apply(lambda x: workclass_encoded[x])
# ...

# %%
education_encoded = {x:y for y,x in enumerate(set(dataset["education_encoder"]))}
dataset["education_encoder"] = dataset['education_encoder'].astype("category")
dataset["education_encoder"] = dataset["education_encoder"].apply(lambda x: education_encoded[x])
print(education_encoded)
dataset.head(5)
# Out:
# {' 10th': 0, ' Masters': 1, ' Bachelors': 2, ' 7th-8th': 3, ' 1st-4th': 4, ' 5th-6th': 5, ' HS-grad': 6, ' Assoc-voc': 7, ' Assoc-acdm': 8, ' Prof-school': 9, ' Preschool': 10, ' 12th': 11, ' Doctorate': 12, ' 11th': 13, ' Some-college': 14, ' 9th': 15}
# <ipython-input-21-f873a267fd88>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["education_encoder"] = dataset['education_encoder'].astype("category")
# <ipython-input-21-f873a267fd88>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
maritalStatus_encoded = {x:y for y,x in enumerate(set(dataset["maritalStatus_encoder"]))}
dataset["maritalStatus_encoder"] = dataset['maritalStatus_encoder'].astype("category")
dataset["maritalStatus_encoder"] = dataset["maritalStatus_encoder"].apply(lambda x: maritalStatus_encoded[x])
print(maritalStatus_encoded)
dataset.head(5)
# Out:
# {' Separated': 0, ' Widowed': 1, ' Never-married': 2, ' Married-civ-spouse': 3, ' Married-AF-spouse': 4, ' Divorced': 5, ' Married-spouse-absent': 6}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# ...

# %%
occupation_encoded = {x:y for y,x in enumerate(set(dataset["occupation_encoder"]))}
dataset["occupation_encoder"] = dataset['occupation_encoder'].astype("category")
dataset["occupation_encoder"] = dataset["occupation_encoder"].apply(lambda x: occupation_encoded[x])
print(occupation_encoded)
dataset.head(3)
# Out:
# {' Other-service': 0, ' Adm-clerical': 1, ' Machine-op-inspct': 2, ' Armed-Forces': 3, ' Priv-house-serv': 4, ' Prof-specialty': 5, ' Transport-moving': 6, ' Craft-repair': 7, ' Sales': 8, ' Protective-serv': 9, ' Exec-managerial': 10, ' Farming-fishing': 11, ' Tech-support': 12, ' Handlers-cleaners': 13}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE    SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# ...

# %%
relationship_encoded = {x:y for y,x in enumerate(set(dataset["relationship_encoder"]))}
dataset["relationship_encoder"] = dataset['relationship_encoder'].astype("category")
dataset["relationship_encoder"] = dataset["relationship_encoder"].apply(lambda x: relationship_encoded[x])
print(relationship_encoded)
dataset.head(3)
# Out:
# {' Unmarried': 0, ' Own-child': 1, ' Wife': 2, ' Husband': 3, ' Other-relative': 4, ' Not-in-family': 5}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE    SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0                  2                 2
# 1  ...   United-States         0                  4                 2
# 2  ...   United-States         0                  3                 6
#
# ...

# %%
race_encoded = {x:y for y,x in enumerate(set(dataset["race_encoder"]))}
dataset["race_encoder"] = dataset['race_encoder'].astype("category")
dataset["race_encoder"] = dataset["race_encoder"].apply(lambda x: race_encoded[x])
print(race_encoded)
dataset.head(3)
# Out:
# {' White': 0, ' Black': 1, ' Amer-Indian-Eskimo': 2, ' Other': 3, ' Asian-Pac-Islander': 4}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE    SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0                  2                 2
# 1  ...   United-States         0                  4                 2
# 2  ...   United-States         0                  3                 6
#
# ...

# %%
sex_encoded = {x:y for y,x in enumerate(set(dataset["sex_encoder"]))}
dataset["sex_encoder"] = dataset['sex_encoder'].astype("category")
dataset["sex_encoder"] = dataset["sex_encoder"].apply(lambda x: sex_encoded[x])
print(sex_encoded)
dataset.head(3)
# Out:
# {' Male': 0, ' Female': 1}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE    SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0                  2                 2
# 1  ...   United-States         0                  4                 2
# 2  ...   United-States         0                  3                 6
#
#    maritalStatus_encoder occupation_encoder relationship_encoder race_encoder  \
# ...

# %%
nativeCountry_encoded = {x:y for y,x in enumerate(set(dataset["nativeCountry_encoder"]))}
dataset["nativeCountry_encoder"] = dataset['nativeCountry_encoder'].astype("category")
dataset["nativeCountry_encoder"] = dataset["nativeCountry_encoder"].apply(lambda x: nativeCountry_encoded[x])
print(nativeCountry_encoded)
dataset.head(3)
# Out:
# {' Taiwan': 0, ' Ecuador': 1, ' Hong': 2, ' South': 3, ' Yugoslavia': 4, ' Haiti': 5, ' Iran': 6, ' Cambodia': 7, ' Honduras': 8, ' Ireland': 9, ' Hungary': 10, ' Cuba': 11, ' United-States': 12, ' Jamaica': 13, ' Peru': 14, ' Scotland': 15, ' Italy': 16, ' Japan': 17, ' England': 18, ' Guatemala': 19, ' Germany': 20, ' El-Salvador': 21, ' Columbia': 22, ' Puerto-Rico': 23, ' Holand-Netherlands': 24, ' Mexico': 25, ' Thailand': 26, ' Canada': 27, ' Portugal': 28, ' China': 29, ' Poland': 30, ' Philippines': 31, ' Greece': 32, ' Nicaragua': 33, ' India': 34, ' Outlying-US(Guam-USVI-etc)': 35, ' Dominican-Republic': 36, ' Trinadad&Tobago': 37, ' France': 38, ' Vietnam': 39, ' Laos': 40}
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE                    30162 non-null  int64
#  1   WORKCLASS              30162 non-null  object
#  2   FNLWGT                 30162 non-null  int64
#  3   EDUCATION              30162 non-null  object
#  4   EDUCATIONNUM           30162 non-null  int64
#  5   MARITALSTATUS          30162 non-null  object
#  6   OCCUPATION             30162 non-null  object
#  7   RELATIONSHIP           30162 non-null  object
#  8   RACE                   30162 non-null  object
#  9   SEX                    30162 non-null  object
#  10  CAPITALGAIN            30162 non-null  int64
#  11  CAPITALLOSS            30162 non-null  int64
#  12  HOURSPERWEEK           30162 non-null  int64
#  13  NATIVECOUNTRY          30162 non-null  object
# ...

# %%
# # dataset['workclass_encoder'].astype('int')
# dataset = dataset.astype('int')
col_category = ['workclass_encoder','education_encoder','maritalStatus_encoder','occupation_encoder','relationship_encoder',
                'race_encoder','sex_encoder','nativeCountry_encoder']
for col in col_category:
  dataset[col]=dataset[col].astype('int')
dataset.head(5)
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0                  2                 2
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
dataset.corr()
#ABOVE50K CORRELATES MOST WITH AGE,EDUCATIONUM,CAPITAL GAIN,HOURSPERWEEK AND RELATIONSHIP ENCODER(RELATIONSHIP)
# Out:
#                             AGE    FNLWGT  EDUCATIONNUM  CAPITALGAIN  \
# AGE                    1.000000 -0.076511      0.043526     0.080154
# FNLWGT                -0.076511  1.000000     -0.044992     0.000422
# EDUCATIONNUM           0.043526 -0.044992      1.000000     0.124416
# CAPITALGAIN            0.080154  0.000422      0.124416     1.000000
# CAPITALLOSS            0.060165 -0.009750      0.079646    -0.032229
# HOURSPERWEEK           0.101599 -0.022886      0.152522     0.080432
# ABOVE50K               0.241998 -0.008957      0.335286     0.221196
# workclass_encoder      0.018376 -0.015006     -0.075912     0.061331
# education_encoder     -0.112423  0.007742     -0.235495    -0.032895
# maritalStatus_encoder  0.220209 -0.030450      0.036684     0.022383
# occupation_encoder     0.060759 -0.003131      0.096652     0.037059
# relationship_encoder   0.132248  0.002427      0.092910     0.020905
# race_encoder          -0.025319 -0.013219      0.002338    -0.005048
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 10))

hm = sns.heatmap(dataset.corr(), cbar=True, vmin=-0.5, vmax=0.5,
                 fmt='.2f', annot_kws={'size': 3}, annot=True, 
                 square=True, cmap=plt.cm.Blues)

# %%
col_category.append('ABOVE50K')
fig, ax = plt.subplots(figsize=(20, 10))

hm = sns.heatmap(dataset[col_category].corr(), cbar=True, vmin=-0.5, vmax=0.5,
                 fmt='.2f', annot_kws={'size': 3}, annot=True, 
                 square=True, cmap=plt.cm.Blues)

# %%
#ABOVE50K vs AGE
ig = plt.figure(figsize=(20, 10))
ax = sns.countplot(data=dataset,x='AGE', hue='ABOVE50K')
ax.set_title('ABOVE50K vs AGE')
#findings- ppl of age 37 to 47 are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs AGE')

# %%
#ABOVE50K vs HOURSPERWEEK
ig = plt.figure(figsize=(25, 10))
ax = sns.countplot(data=dataset,x='HOURSPERWEEK', hue='ABOVE50K')
ax.set_title('ABOVE50K vs HOURSPERWEEK')
#findings- ppl who work around 40 and 50 hours are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs HOURSPERWEEK')

# %%
#ABOVE50K vs WORKCLASS
ig = plt.figure(figsize=(20, 10))
ax = sns.countplot(data=dataset,x='WORKCLASS', hue='ABOVE50K')
ax.set_title('ABOVE50K vs WORKCLASS')
#findings- ppl who work in private sector are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs WORKCLASS')

# %%
#ABOVE50K vs EDUCATION
ig = plt.figure(figsize=(20, 10))
ax = sns.countplot(data=dataset,x='EDUCATION', hue='ABOVE50K')
ax.set_title('ABOVE50K vs EDUCATION')
#findings- ppl who have done Bachelors and HS-grad are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs EDUCATION')

# %%
#ABOVE50K vs OCCUPATION
ig = plt.figure(figsize=(25, 10))
ax = sns.countplot(data=dataset,x='OCCUPATION', hue='ABOVE50K')
ax.set_title('ABOVE50K vs OCCUPATION')
#findings- ppl who work as Exec-managerial and Prof-speciality are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs OCCUPATION')

# %%
#ABOVE50K vs SEX
ig = plt.figure(figsize=(10, 10))
ax = sns.countplot(data=dataset,x='SEX', hue='ABOVE50K')
ax.set_title('ABOVE50K vs SEX')
#findings- ppl who work as Exec-managerial and Prof-speciality are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs SEX')

# %%
#ABOVE50K vs RACE
ig = plt.figure(figsize=(15, 10))
ax = sns.countplot(data=dataset,x='RACE', hue='ABOVE50K')
ax.set_title('ABOVE50K vs RACE')
#findings- ppl whos race is white are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs RACE')

# %%
#ABOVE50K vs MARITALSTATUS
ig = plt.figure(figsize=(15, 10))
ax = sns.countplot(data=dataset,x='MARITALSTATUS', hue='ABOVE50K')
ax.set_title('ABOVE50K vs MARITALSTATUS')
#findings- ppl who are Married-civ-spouse are more prone to earn a salary of more than 50k
# Out:
# Text(0.5, 1.0, 'ABOVE50K vs MARITALSTATUS')

# %% [markdown]
# # FEATURE SCALING

# %%
temp_dataset = dataset.copy()
temp_dataset.head(5)
temp_dataset.drop(['WORKCLASS','FNLWGT', 'EDUCATION','MARITALSTATUS','OCCUPATION','RELATIONSHIP','RACE','SEX','NATIVECOUNTRY'], axis=1, inplace=True)
# temp_dataset.drop(['FNLWGT'], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(temp_dataset)

scaled_df = pd.DataFrame(temp_dataset, columns=temp_dataset.columns)
scaled_df.head()
# Out:
#    AGE  EDUCATIONNUM  CAPITALGAIN  CAPITALLOSS  HOURSPERWEEK  ABOVE50K  \
# 0   39            13         2174            0            40         0
# 1   50            13            0            0            13         0
# 2   38             9            0            0            40         0
# 3   53             7            0            0            40         0
# 4   28            13            0            0            40         0
#
#    workclass_encoder  education_encoder  maritalStatus_encoder  \
# 0                  2                  2                      2
# 1                  4                  2                      3
# 2                  3                  6                      5
# 3                  3                 13                      3
# 4                  3                  2                      3
#
#    occupation_encoder  relationship_encoder  race_encoder  sex_encoder  \
# 0                   1                     5             0            0
# ...

# %%
temp_dataset.head(5)
# Out:
#    AGE  EDUCATIONNUM  CAPITALGAIN  CAPITALLOSS  HOURSPERWEEK  ABOVE50K  \
# 0   39            13         2174            0            40         0
# 1   50            13            0            0            13         0
# 2   38             9            0            0            40         0
# 3   53             7            0            0            40         0
# 4   28            13            0            0            40         0
#
#    workclass_encoder  education_encoder  maritalStatus_encoder  \
# 0                  2                  2                      2
# 1                  4                  2                      3
# 2                  3                  6                      5
# 3                  3                 13                      3
# 4                  3                  2                      3
#
#    occupation_encoder  relationship_encoder  race_encoder  sex_encoder  \
# 0                   1                     5             0            0
# ...

# %%
dataset.head(5)
# Out:
#    AGE          WORKCLASS  FNLWGT   EDUCATION  EDUCATIONNUM  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#          MARITALSTATUS          OCCUPATION    RELATIONSHIP    RACE      SEX  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    ...   NATIVECOUNTRY  ABOVE50K  workclass_encoder education_encoder  \
# 0  ...   United-States         0                  2                 2
# ...

# %%
dataset['ABOVE50K'].value_counts().plot(kind='barh')
dataset['ABOVE50K'].value_counts() #dataset is biased towards 0 
#We will perform Logistic regression on our dataset in two ways
#With equal number of training examples of both classes
#With the whole dataset
# Out:
# 0    22654
# 1     7508
# Name: ABOVE50K, dtype: int64

# %% [markdown]
# # Logistic regression without sampling (whole dataset)

# %%
X = temp_dataset[['AGE','EDUCATIONNUM','CAPITALGAIN','CAPITALLOSS','HOURSPERWEEK','workclass_encoder','education_encoder','maritalStatus_encoder','occupation_encoder','relationship_encoder',
                 'race_encoder','sex_encoder','nativeCountry_encoder']]
y = temp_dataset['ABOVE50K']

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=10)
logisticregression = LogisticRegression(C=100, max_iter=50, penalty='l2', solver='liblinear').fit(X_train, y_train)#c = 1/ lam
print("training set score: %f" % logisticregression.score(X_train, y_train))
print("test set score: %f" % logisticregression.score(X_test, y_test))
logisticregression.fit(X_train, y_train)
print(X.shape)
print(y.shape)
# Out:
# training set score: 0.821493
# test set score: 0.819520
# (30162, 13)
# (30162,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LogisticRegression(fit_intercept=False, solver='lbfgs', C=.5, max_iter=5000),
X = X_train,
y = y_train, cv = 10, scoring="accuracy")

# %%
print('Training scores:\n\n', train_sizes)
print('\n', '-' * 70) # separator to make the output easy to read
print('\nValidation scores:\n\n', validation_scores)
# Out:
# Training scores:
#
#  [ 2035  6616 11196 15777 20358]
#
#  ----------------------------------------------------------------------
#
# Validation scores:
#
#  [[0.79805568 0.80636605 0.78381963 0.81255526 0.80592396 0.81476569
#   0.80548187 0.80238727 0.80415561 0.79000884]
#  [0.79673    0.80946065 0.78603006 0.81741821 0.80327144 0.81476569
#   0.80238727 0.80548187 0.80725022 0.79310345]
#  [0.80070703 0.80813439 0.78603006 0.8178603  0.8045977  0.81653404
#   0.80371353 0.8045977  0.80725022 0.79487179]
#  [0.79938135 0.80769231 0.78691424 0.81918656 0.80371353 0.81741821
#   0.80680813 0.8045977  0.80769231 0.79487179]
#  [0.80070703 0.80725022 0.78779841 0.81918656 0.8045977  0.81874447
#   0.80813439 0.8045977  0.80548187 0.79487179]]

# %%
train_scores_mean = train_scores.mean(axis = 1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a logistic regression model', fontsize = 18, y = 1.03)
plt.legend()
# plt.ylim(0.7675,.7775)

# %%
train_sizes = [10,40,80,100,150,200,300, 400,500, 600, 700, 800,1500,4000,7500]
train_sizes, train_scores, validation_scores = learning_curve(
estimator = logisticregression,
X = X_train,
y = y_train, train_sizes = train_sizes,
scoring = 'neg_mean_squared_error')

train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curve for Logistic Regression', fontsize = 18, y = 1)
plt.ylim(0,0.5)
plt.legend()

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=LogisticRegression(C=10, max_iter=50, multi_class='ovr', solver='liblinear',penalty='l2'),
                                                       X=X_train, y=y_train,cv=5, train_sizes=np.linspace(0.1, 1.0, 10),n_jobs=1)
#
# Calculate training and test mean and std
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()
#accuracy curve

# %%
print(set(y_train))
# Out:
# {0, 1}

# %%
y_pred = logisticregression.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8195199575653096

# %%
from sklearn.metrics import confusion_matrix
con_mat = confusion_matrix(y_test, logisticregression.predict(X_test))
print(con_mat)
# Out:
# [[5311  345]
#  [1016  869]]

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,5))   
ax = sns.heatmap(con_mat, annot=True, ax=ax, fmt = 'g')
ax.set_xlabel('Actual Values')
ax.set_ylabel('Predicted')
ax.set_xticklabels(['ABOVE50K', 'BELOW50K'])
ax.set_yticklabels(['ABOVE50K', 'BELOW50K'], rotation=90, va='center')
# Out:
# [Text(0, 0.5, 'ABOVE50K'), Text(0, 1.5, 'BELOW50K')]

# %%
dataset['ABOVE50K'].value_counts() #dataset is biased towards 0 but somehow the model is showing good accuracy
# Out:
# 0    22654
# 1     7508
# Name: ABOVE50K, dtype: int64

# %%
import yellowbrick.classifier
from yellowbrick.classifier import ROCAUC
visualizer = ROCAUC(logisticregression, classes=["ABOVE50K", "BELOW50K"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.savefig('ROC Logistic Regression.jpg')

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      5656
#            1       0.72      0.46      0.56      1885
#
#     accuracy                           0.82      7541
#    macro avg       0.78      0.70      0.72      7541
# weighted avg       0.81      0.82      0.81      7541

# %%
#HYPERPARAMETER TUNING
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
max_iter = [50, 100, 150, 200, 250, 300]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values, max_iter = max_iter)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=logisticregression, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',
                           error_score=0)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
#model is not retrained again after hyperparameter tuning as the accuracy doesn't increase much.
# Out:
# Best: 0.821431 using {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.821309 (0.004864) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.793195 (0.005370) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.821431 (0.005185) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.781016 (0.004977) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'sag'}
# 0.821287 (0.004875) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.797648 (0.005222) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.821431 (0.005185) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.786321 (0.004822) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'sag'}
# 0.821287 (0.004875) with: {'C': 100, 'max_iter': 150, 'penalty': 'l2', 'solver': 'newton-cg'}
# ...

# %% [markdown]
# # Logistic Regression with equal training examples of both classes

# %%
#Taking equal numbers of training examples for both classes
X = temp_dataset[['AGE','EDUCATIONNUM','CAPITALGAIN','CAPITALLOSS','HOURSPERWEEK','workclass_encoder',
                  'education_encoder','maritalStatus_encoder','occupation_encoder','relationship_encoder','race_encoder','sex_encoder']]
y = temp_dataset['ABOVE50K']

# %%
X
# Out:
#        AGE  EDUCATIONNUM  CAPITALGAIN  CAPITALLOSS  HOURSPERWEEK  \
# 0       39            13         2174            0            40
# 1       50            13            0            0            13
# 2       38             9            0            0            40
# 3       53             7            0            0            40
# 4       28            13            0            0            40
# ...    ...           ...          ...          ...           ...
# 32556   27            12            0            0            38
# 32557   40             9            0            0            40
# 32558   58             9            0            0            40
# 32559   22             9            0            0            20
# 32560   52             9        15024            0            40
#
#        workclass_encoder  education_encoder  maritalStatus_encoder  \
# 0                      2                  2                      2
# ...

# %%
y
y.shape
# Out:
# (30162,)

# %%
ones = temp_dataset.loc[temp_dataset['ABOVE50K'] == 1]
zeros = temp_dataset.loc[temp_dataset['ABOVE50K'] == 0]
final_df = pd.concat([ones, zeros[:7508]])
print(len(final_df.loc[final_df['ABOVE50K'] == 1]))
len(final_df.loc[final_df['ABOVE50K'] == 0])
print(final_df.shape)
# Out:
# 7508
# (15016, 14)

# %%
X = final_df[['AGE','EDUCATIONNUM','CAPITALGAIN','CAPITALLOSS','HOURSPERWEEK','workclass_encoder',
                  'education_encoder','maritalStatus_encoder','occupation_encoder','relationship_encoder','race_encoder','sex_encoder']]
y = final_df['ABOVE50K']

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=10)
logisticregression = LogisticRegression(C=100, max_iter=100,penalty='l2', solver='newton-cg').fit(X_train, y_train)#c = 1/ lam
print("training set score: %f" % logisticregression.score(X_train, y_train))
print("test set score: %f" % logisticregression.score(X_test, y_test))
logisticregression.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")
# training set score: 0.758125
# test set score: 0.763719
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:437: LineSearchWarning: Rounding errors prevent the line search from converging
#   warn(msg, LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve
train_sizes, train_scores, validation_scores = learning_curve(
estimator = LogisticRegression(),
X = X_train,
y = y_train, cv = 10, scoring="accuracy")
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
train_scores_mean = train_scores.mean(axis = 1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for logistic regression model', fontsize = 18, y = 1.03)
plt.legend()

# %%
y_pred = logisticregression.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76      1870
#            1       0.77      0.76      0.76      1884
#
#     accuracy                           0.76      3754
#    macro avg       0.76      0.76      0.76      3754
# weighted avg       0.76      0.76      0.76      3754

# %%
#plotting confusion matrix
from sklearn.metrics import confusion_matrix
con_mat = confusion_matrix(y_test, logisticregression.predict(X_test))
print(con_mat)
# Out:
# [[1437  433]
#  [ 454 1430]]

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(7,5))   
ax = sns.heatmap(con_mat, annot=True, ax=ax, fmt = 'g')
ax.set_xlabel('Actual Values')
ax.set_ylabel('Predicted')
ax.set_xticklabels(['ABOVE50K', 'BELOW50K'])
ax.set_yticklabels(['ABOVE50K', 'BELOW50K'], rotation=90, va='center')
# Out:
# [Text(0, 0.5, 'ABOVE50K'), Text(0, 1.5, 'BELOW50K')]

# %%
#plotting roc curve for sampled dataset
import yellowbrick.classifier
from yellowbrick.classifier import ROCAUC
visualizer = ROCAUC(logisticregression, classes=["ABOVE50K", "BELOW50K"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
train_sizes = [10,40,80,100,150,200,300, 400,500, 600, 700, 780,1500,2500,5000,7500,8000]
train_sizes, train_scores, validation_scores = learning_curve(
estimator = logisticregression,
X = X_train,
y = y_train, train_sizes = train_sizes,
scoring = 'neg_mean_squared_error')

train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curve for Logistic Regression', fontsize = 18, y = 1.03)
plt.ylim(0,0.5)
plt.legend()
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/optimize.py:203: UserWarning: Line Search failed
#   warnings.warn("Line Search failed")

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=LogisticRegression(C=10, max_iter=50,
                                                                                     multi_class='ovr', solver='liblinear',
                                                                                     penalty='l2'), X=X_train, y=y_train,cv=5,
                                                         train_sizes=np.linspace(0.1, 1.0, 10),n_jobs=1)
# Calculate training and test mean and std
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
# Plot the learning curve
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()

# %%
#HYPERPARAMETER TUNING
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
max_iter = [50, 100, 150, 200, 250, 300]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values, max_iter = max_iter)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=logisticregression, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',
                           error_score=0)
grid_result = grid_search.fit(X, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
#model is not retrained again after hyperparameter tuning as the accuracy doesn't increase much.
# Out:
# Best: 0.760968 using {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.760946 (0.010666) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.662183 (0.012663) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.740412 (0.011215) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.618741 (0.008912) with: {'C': 100, 'max_iter': 50, 'penalty': 'l2', 'solver': 'sag'}
# 0.760968 (0.010510) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.695082 (0.011397) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.740412 (0.011215) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.618807 (0.008949) with: {'C': 100, 'max_iter': 100, 'penalty': 'l2', 'solver': 'sag'}
# 0.760968 (0.010510) with: {'C': 100, 'max_iter': 150, 'penalty': 'l2', 'solver': 'newton-cg'}
# ...

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76      1870
#            1       0.77      0.76      0.76      1884
#
#     accuracy                           0.76      3754
#    macro avg       0.76      0.76      0.76      3754
# weighted avg       0.76      0.76      0.76      3754

# %% [markdown]
# # KNN (For equal number of sample of both classes)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

# %%
def find_best_k(X_train, y_train, X_test, y_test, min_k=1, max_k=25):
    best_k = 0
    best_score = 0.0
    for k in range(min_k, max_k+1, 2):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        preds = knn.predict(X_test)
        f1 = f1_score(y_test, preds, average='micro')
        if f1 > best_score:
            best_k = k
            best_score = f1
    
    print("Best Value for k: {}".format(best_k))
    print("F1-Score: {}".format(best_score))

# %%
find_best_k(X_train, y_train, X_test, y_test, min_k=1, max_k=25)
# Out:
# Best Value for k: 9
# F1-Score: 0.7903569525839105

# %%
#k9 has the highest value so we chose it

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred = knn.predict(X_test)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
disp = metrics.ConfusionMatrixDisplay(metrics.confusion_matrix(y_test, y_pred))
disp.plot()

# %%
accuracy = (con_mat[0,0] + con_mat[1,1]) / con_mat.sum()
print("Accuracy: ", accuracy * 100)
# Out:
# Accuracy:  76.37187000532765

# %%
#Learning curve
from sklearn.model_selection import learning_curve
train_sizes, train_scores, validation_scores = learning_curve(
estimator = KNeighborsClassifier(),
X = X_train,
y = y_train, cv = 10, scoring="accuracy")

# %%
print('Training scores:\n\n', train_sizes)
print('\n', '-' * 70) # separator to make the output easy to read
print('\nValidation scores:\n\n', validation_scores)
# Out:
# Training scores:
#
#  [ 1013  3293  5574  7854 10135]
#
#  ----------------------------------------------------------------------
#
# Validation scores:
#
#  [[0.74001775 0.73913043 0.73001776 0.73978686 0.73534636 0.70159858
#   0.73978686 0.73357016 0.70781528 0.73712256]
#  [0.76574978 0.76663709 0.76376554 0.75044405 0.77175844 0.74600355
#   0.74955595 0.76021314 0.75666075 0.76820604]
#  [0.77196096 0.77462289 0.77975133 0.75222025 0.79573712 0.76110124
#   0.76110124 0.78419183 0.75843694 0.77264654]
#  [0.7755102  0.78172138 0.77886323 0.76465364 0.78774423 0.77442274
#   0.76642984 0.79840142 0.77175844 0.77264654]
#  [0.77994676 0.78349601 0.78241563 0.78330373 0.78330373 0.78952043
#   0.77264654 0.79396092 0.78685613 0.78596803]]

# %%
train_scores_mean = train_scores.mean(axis = 1)
validation_scores_mean = validation_scores.mean(axis=1)

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('MSE', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves for a KNN model', fontsize = 18, y = 0)
plt.legend()

# %%
train_sizes = [10,40,80,100,150,200,300, 400,500, 600, 700, 780,1000,1500,2500,3000,5000,7000,9000]
train_sizes, train_scores, validation_scores = learning_curve(
estimator = knn,
X = X_train,
y = y_train, train_sizes = train_sizes,
scoring = 'neg_mean_squared_error')

train_scores_mean = -train_scores.mean(axis = 1)
validation_scores_mean = -validation_scores.mean(axis = 1)
plt.style.use('seaborn')
plt.plot(train_sizes, train_scores_mean, label = 'Training error')
plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curve for KNN', fontsize = 18, y = 1.03)
plt.ylim(0,0.8)
plt.legend()
#Learning curve wrt to loss

# %%
train_sizes, train_scores, test_scores = learning_curve(estimator=knn,
                                                       X=X_train, y=y_train,cv=5, train_sizes=np.linspace(0.1, 1.0, 10),n_jobs=1)
#
# Calculate training and test mean and std
#
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
#
# Plot the learning curve
#
plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Accuracy')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Validation Accuracy')
plt.title('Learning Curve')
plt.xlabel('Training Data Size')
plt.ylabel('Model accuracy')
plt.grid()
plt.legend(loc='lower right')
plt.show()
#accuracy curve

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
y_pred = logisticregression.predict(X_test)
y_pred

print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76      1870
#            1       0.77      0.76      0.76      1884
#
#     accuracy                           0.76      3754
#    macro avg       0.76      0.76      0.76      3754
# weighted avg       0.76      0.76      0.76      3754

# %%
from sklearn import svm
clf = svm.SVC(C=0.5, gamma=0.01, kernel='poly')

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
def find_best_k(X_train, y_train, X_test, y_test, min_k=1, max_k=25):
    best_k = 0
    best_score = 0.0
    for k in range(min_k, max_k+1, 2):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        preds = knn.predict(X_test)
        f1 = f1_score(y_test, preds, average='micro')
        if f1 > best_score:
            best_k = k
            best_score = f1
    
    print("Best Value for k: {}".format(best_k))
    print("F1-Score: {}".format(best_score))

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
preds = knn.predict(X_test)

# %%
import yellowbrick.classifier
from yellowbrick.classifier import ROCAUC
visualizer = ROCAUC(knn, classes=["ABOVE50K", "BELOW50K"])

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
